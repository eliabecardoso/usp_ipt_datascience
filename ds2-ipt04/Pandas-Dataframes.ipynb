# %% [markdown]
# # Pandas Dataframes

# %%
import pandas as pd
import numpy as np

# %%
#Observe que já carregamos o dataframe e já definimos o índice
gm=pd.read_csv('c:\\dados\\gm_data.csv',index_col=['date'])

# %%
gm.head()
# Out:
#              open   high    low  close    volume Name
# date
# 2013-02-08  28.54  28.73  28.50  28.57   6316645   GM
# 2013-02-11  28.51  28.65  28.35  28.53   5589830   GM
# 2013-02-12  28.43  28.75  28.24  28.55   7175443   GM
# 2013-02-13  28.75  28.87  28.44  28.67   9281737   GM
# 2013-02-14  28.74  29.36  27.67  27.75  19226730   GM

# %%
gm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1259 entries, 2013-02-08 to 2018-02-07
# Data columns (total 7 columns):
# open      1259 non-null float64
# high      1259 non-null float64
# low       1259 non-null float64
# close     1259 non-null float64
# volume    1259 non-null int64
# Name      1259 non-null object
# status    1259 non-null object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 118.7+ KB

# %% [markdown]
# Ao selecionar uma coluna do dataframe, temos uma série

# %%
gm['volume'].head()
# Out:
# date
# 2013-02-08     6316645
# 2013-02-11     5589830
# 2013-02-12     7175443
# 2013-02-13     9281737
# 2013-02-14    19226730
# Name: volume, dtype: int64

# %% [markdown]
# Vamos criar uma nova coluna 'status' com valor 'normal' para todas as amostras

# %%
# Out:
#              open   high    low  close    volume Name  status
# date
# 2018-02-01  42.12  42.60  41.95  42.43   9629833   GM  normal
# 2018-02-02  42.22  42.27  40.85  41.00  13982144   GM  normal
# 2018-02-05  40.98  41.67  39.51  39.54  19660620   GM  normal
# 2018-02-06  40.06  42.23  40.00  41.86  26988259   GM  normal
# 2018-02-07  41.80  43.56  41.65  42.39  19402866   GM  normal

# %% [markdown]
# Nos dias em que o fechamento for maior que quarenta, mudaremos o status para 'alto'

# %%
# Out:
#              open   high    low  close    volume Name  status
# date
# 2018-02-01  42.12  42.60  41.95  42.43   9629833   GM    alto
# 2018-02-02  42.22  42.27  40.85  41.00  13982144   GM    alto
# 2018-02-05  40.98  41.67  39.51  39.54  19660620   GM  normal
# 2018-02-06  40.06  42.23  40.00  41.86  26988259   GM    alto
# 2018-02-07  41.80  43.56  41.65  42.39  19402866   GM    alto

# %% [markdown]
# Obtenha as datas onde a abertura é menor que o fechamento, qual a probabilidade disso acontecer (com base no período registrado)?

# %%
# Out:
# (Index(['2013-02-08', '2013-02-11', '2013-02-12', '2013-02-15', '2013-02-22',
#         '2013-02-26', '2013-02-27', '2013-03-01', '2013-03-05', '2013-03-06',
#         ...
#         '2018-01-08', '2018-01-11', '2018-01-17', '2018-01-22', '2018-01-23',
#         '2018-01-24', '2018-01-26', '2018-02-01', '2018-02-06', '2018-02-07'],
#        dtype='object', name='date', length=629), 0.4996028594122319)

# %% [markdown]
# Vamos abrir um novo dataframe com dados de carros

# %%
#Observe que o separador ';' não é default
cars=pd.read_csv('c:\\dados\\cars-uci-linked.csv',sep=';')
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8          3070       130.0    3504           120    70
# 1  15.0          8          3500       165.0    3693           115    70
# 2  18.0          8          3180       150.0    3436           110    70
# 3  16.0          8          3040       150.0    3433           120    70
# 4  17.0          8          3020       140.0    3449           105    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# Vamos aos dados gerais (tipos, nulos, quantidades)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       406 non-null int64
# displacement    406 non-null int64
# horsepower      400 non-null float64
# weight          406 non-null int64
# acceleration    406 non-null int64
# year            406 non-null int64
# origin          406 non-null int64
# name            406 non-null object
# dtypes: float64(2), int64(6), object(1)
# memory usage: 28.6+ KB

# %% [markdown]
# Uma possibilidade de tirar os nulos é dropna()...mas daí todas as linhas que tiverem nulos serão eliminadas..

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 405
# Data columns (total 9 columns):
# mpg             392 non-null float64
# cylinders       392 non-null int64
# displacement    392 non-null int64
# horsepower      392 non-null float64
# weight          392 non-null int64
# acceleration    392 non-null int64
# year            392 non-null int64
# origin          392 non-null int64
# name            392 non-null object
# dtypes: float64(2), int64(6), object(1)
# memory usage: 30.6+ KB

# %% [markdown]
# Uma possibilidade é fillna(val)..ou seja, preencher os missing values com um valor fixo, mas podemos ter estratégias mais elaboradas..

# %% [markdown]
# Vamos "standardizar" a feature MPG...cada valor será substituído por ele menos a média/desvio padrão

# %%
# Out:
# (1.0, -4.1066923104757065e-17)

# %% [markdown]
# Agora, vamos montar dois arrays(numpy), X com as features horsepower e weight
# e y com MPG

# %% [markdown]
# Um pouco mais de filtros e loc/iloc
# Vamos trocar o nome dos carros com mais de 4000kg por Barca

# %%
# Out:
#         mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  0.000000          8          3070       130.0    3504           120    70
# 1 -1.082115          8          3500       165.0    3693           115    70
# 2 -0.697747          8          3180       150.0    3436           110    70
# 3 -0.953992          8          3040       150.0    3433           120    70
# 4 -0.825870          8          3020       140.0    3449           105    70
# 5 -1.082115          8          4290       198.0    4341           100    70
# 6 -1.210238          8          4540       220.0    4354            90    70
# 7 -1.210238          8          4400       215.0    4312            85    70
# 8 -1.210238          8          4550       225.0    4425           100    70
# 9 -1.082115          8          3900       190.0    3850            85    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# ...

# %% [markdown]
# Agora filtre as linhas com as "Barcas"

# %%
# Out:
#           mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 5   -1.082115          8          4290       198.0    4341           100
# 6   -1.210238          8          4540       220.0    4354            90
# 7   -1.210238          8          4400       215.0    4312            85
# 8   -1.210238          8          4550       225.0    4425           100
# 31  -1.722730          8          3600       215.0    4615           140
# 32  -1.722730          8          3070       200.0    4376           150
# 33  -1.594607          8          3180       210.0    4382           135
# 34  -1.850853          8          3040       193.0    4732           185
# 45  -1.210238          8          3500       165.0    4209           120
# 46  -1.210238          8          4000       175.0    4464           115
# 47  -1.210238          8          3510       153.0    4154           135
# 48  -1.210238          8          3180       150.0    4096           130
# ...

# %% [markdown]
# Drop em features...usamos drop...retire a feature cylinders do dataframe

# %%
# Out:
#         mpg  displacement  horsepower  weight  acceleration  year  origin  \
# 0  0.000000          3070       130.0    3504           120    70       1
# 1 -1.082115          3500       165.0    3693           115    70       1
# 2 -0.697747          3180       150.0    3436           110    70       1
# 3 -0.953992          3040       150.0    3433           120    70       1
# 4 -0.825870          3020       140.0    3449           105    70       1
#
#                         name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino
